# %% [markdown]
# # <font color='#306364'>Data Exploration</font> <a class="anchor" id="toc"></a>
# * [I - Packages and Data Imports](#import)
# * [II - Data Exploration](#exploration)
# * [III - Data Visualization and Data Distribution](#visualization)

# %% [markdown]
# # <font color='#306364'>II. Packages and Data Import</font> <a class="anchor" id="import"></a>
# [Back to Contents](#toc)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from category_encoders import TargetEncoder
from category_encoders.m_estimate import MEstimateEncoder
import category_encoders as ce
import seaborn as sns
from numpy import mean
from numpy import std
from sqlalchemy import create_engine

# %%
# Loading the dataset and visualizing summary statistics
username = 'admin'
password = 'admin' 
host_name = 'hostname'
port = 5432
db_name = 'operation-db'
schema = 'companydata'

conn_str = 'postgresql://{}:{}@{}:{}/{}'.format(username, password, host_name, port, db_name)
conn_args = {'options': '-csearch_path={}'.format(schema)}

with open('queries/table1.sql') as query_from_file:
    df = pd.read_sql_query(query_from_file.read(), engine)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-6311ad48a5b5> in <module>()
#      10 conn_args = {'options': '-csearch_path={}'.format(schema)}
#      11
# ---> 12 with open('queries/select_movies_and_genres.sql') as query_from_file:
#      13     df = pd.read_sql_query(query_from_file.read(), engine)
#      14
#
# FileNotFoundError: [Errno 2] No such file or directory: 'queries/select_movies_and_genres.sql'

# %%
# Check first 5 rows
df.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-4b8262113baf> in <module>()
#       1 # Check first 5 rows
# ----> 2 df.head(5)
#
# NameError: name 'df' is not defined

# %% [markdown]
# # <font color='#306364'>II. Data Exploration</font> <a class="anchor" id="exploration"></a>
# [Back to Contents](#toc)

# %%
# Check data types in ds
df.info()
df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-07af50e05b81> in <module>()
#       1 # Check data types in ds
# ----> 2 df.info()
#       3 df.shape
#
# NameError: name 'df' is not defined

# %%
#Check if there are duplicates
df.duplicated().sum() #No duplicate observations
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-b40a11cd15d0> in <module>()
#       1 #Check if there are duplicates
# ----> 2 df.duplicated().sum() #No duplicate observations
#
# NameError: name 'df' is not defined

# %%
#Summary statistics for numeric variables 
dStat = df.describe().T
dStat['Missings'] = df.shape[0] - dStat['count']
print(dStat)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-bf8d34bb8579> in <module>()
#       1 #Summary statistics for numeric variables
# ----> 2 dStat = df.describe().T
#       3 dStat['Missings'] = df.shape[0] - dStat['count']
#       4 print(dStat)
#
# NameError: name 'df' is not defined

# %%
#Descriptive statistics for categorical variables
df.describe(include = ['O'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-413acb937cf9> in <module>()
#       1 #Descriptive statistics for categorical variables
# ----> 2 df.describe(include = ['O'])
#
# NameError: name 'df' is not defined

# %%
#Explore cardinality of each feature
df.nunique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-72a8c3aec3fd> in <module>()
#       1 #Explore cardinality of each feature
# ----> 2 df.nunique()
#
# NameError: name 'df' is not defined

# %% [markdown]
# # <font color='#306364'>III. Data Visualization and Variables Distribution</font> <a class="anchor" id="visualization"></a>
# [Back to Contents](#toc)

# %% [markdown]
# #### 1. Class Imbalance

# %% [markdown]
# ####  2. Variables distribution & distribution with target variable
